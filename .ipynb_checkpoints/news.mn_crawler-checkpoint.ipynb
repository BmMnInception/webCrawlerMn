# %% [markdown]
# # Web Crawlers: News.mn

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

# %% [markdown]
# ### Мэдээний сайтын нүүр хуудасыг авах

# %% [markdown]
# URL тодорхойлох:

# %%
# url тодорхойлох
url = "https://news.mn/angilal/shar-medee/"

# %% [markdown]
# Мэдээллийн жагсаалт:

# %%
# Хүсэлт
r1 = requests.get(url)
r1.status_code

# Нүүр хуудасны агуулгыг хадгалах болно
coverpage = r1.content

# Soup үүсгэх
soup1 = BeautifulSoup(coverpage, 'html5lib')

# Мэдээ таних
coverpage_news = soup1.find_all('h1', class_='entry-title')
len(coverpage_news)
# Out:
# 52

# %% [markdown]
# Элемент бүр мэдээллийн линкийг агуулсан байна:

# %%
coverpage_news[4]
# Out:
# <h1 class="entry-title"><a href="https://news.mn/r/2290550/">Жо Байден өөрийн дэд ерөнхийлөгчөөр Мишель Обамаг сонгожээ</a></h1>

# %% [markdown]
# ### Нийтлэлээс текстийг гаргаж авцгаая:

# %% [markdown]
# Эхлээд хүссэн нийтлэлийнхээ тоог тодорхойлно:

# %%
number_of_articles = 52

# %%
# Контент, холбоос, гарчигийн хоосон жагсаалт
news_contents = []
list_links = []
list_titles = []

for n in np.arange(0, number_of_articles):
        
    # Нийтлэл биш тул "live" хуудсыг орхих хэрэгтэй
    if "live" in coverpage_news[n].find('a')['href']:  
        continue
    
    # Нийтлэлийн холбоосыг авч байна
    link = coverpage_news[n].find('a')['href']
    list_links.append(link)
    
    # Гарчиг авч байна
    title = coverpage_news[n].find('a').get_text()
    list_titles.append(title)
    
    # Агуулга унших (энэ нь догол мөрүүдээр хуваагдана)
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html5lib')
    body = soup_article.find_all('div', class_='has-content-area')
    x = body[0].find_all('p')
    
    # Догол мөрүүдийг нэгтгэх
    list_paragraphs = []
    for p in np.arange(0, len(x)):
        paragraph = x[p].get_text()
        list_paragraphs.append(paragraph)
        final_article = " ".join(list_paragraphs)
        
    news_contents.append(final_article)

# %% [markdown]
# Тэдгээрийг оруулцгаая:
# * Өгөгдлийг авна (`df_features`)
# * Нийтлэлийн гарчиг болон линкийг авна (`df_show_info`)

# %%
# df_features
df_features = pd.DataFrame(
     {'Нийтлэлийн мэдээлэл': news_contents,
      'Ангилал':'Шар мэдээ',
    })

# df_show_info
df_show_info = pd.DataFrame(
    {'Нийтлэлийн гарчиг': list_titles,
     'Нийтлэлийн линк': list_links})

# %%
df_features.head()
# Out:
#                                  Нийтлэлийн мэдээлэл    Ангилал
# 0  Бээжингийн амьтны хүрээлэнд нэгэн Бенгалийн ца...  Шар мэдээ
# 1  Цахим орчинд нэгэн инээдтэй ч юм шиг эмгэнэлтэ...  Шар мэдээ
# 2  Хотын дарга С.Амарсайханы захирамжаар Сүхбаата...  Шар мэдээ
# 3  Дархан-Улаанбаатар чиглэлийн авто замыг цаг ху...  Шар мэдээ
# 4  Жо Байден арваннэгдүгээр сард болох сонгуульда...  Шар мэдээ

# %%
df_features.to_csv(r'шарМэдээ.csv', index = False)

# %%
df_show_info
# Out:
#                                     Нийтлэлийн гарчиг  \
# 0   Дүүргийн онцгой комисс цахим хурал зохион байг...
# 1                    Яагаад амны хаалт зүүх ёстой вэ?
# 2      Шүлхий өвчнөөс урьдчилан сэргийлэх вакцин хийв
# 3      Нүхэн жорлонгийн ариутгал 76 хувьтай явж байна
# 4   Хувийн хэвшлийн эмнэлгүүдэд “Ковид-19” халдвар...
# 5   Нийслэлд шинээр 122 га талбайд ногоон байгуула...
# 6   Зөвшөөрөлгүй гаражуудыг буулгаж, Өрхийн эрүүл ...
# 7   Зайлшгүй шалтгаантай иргэдийг Улаанбаатарт нэв...
# 8      Коронавируст халдварын нөхцөл байдлын мэдээлэл
# 9   "Халдвар авсан жолооч хүүтэйгээ уулзсан байж б...
# 10           Сургалтын төвүүд дампуурлаа зарлаж байна
# 11  "Л.Энхболд, Г.Солтан нарыг яллагдагчаар албада...
# 12                    243,631 ширхэг хувьцаа арилжжээ
# 13   Таван нам 2020 оны сонгуульд оролцохоо мэдэгджээ
# 14  Яаёой Кусама Covid-19-ийг "зайлуулах" шүлэг би...
# 15  Сонгуулийн хуулийн зарим заалт Үндсэн хууль зө...
# 16      Амьтны хүрээлэнгийн барын сэтгэл өвдөм бичлэг
# 17  Аж ахуйн нэгж байгууллагууд хандивын аянд нэгд...
# 18  Дүүргийн онцгой комисс цахим хурал зохион байг...
# 19                   Яагаад амны хаалт зүүх ёстой вэ?
# 20     Шүлхий өвчнөөс урьдчилан сэргийлэх вакцин хийв
# 21     Нүхэн жорлонгийн ариутгал 76 хувьтай явж байна
# 22  Ерөнхийлөгч Улсын онцгой комисст тусгай зориул...
# 23  Хувийн хэвшлийн эмнэлгүүдэд “Ковид-19” халдвар...
# 24  Нийслэлд шинээр 122 га талбайд ногоон байгуула...
# 25  Ардчилсан намын мөрийн хөтөлбөрийг хуульд нийц...
# 26      Covid-19 хувьссаар 270 дахин хөнөөлтэй болжээ
# 27  Эдийн засаг, нийгмийг 2021 онд хөгжүүлэх үндсэ...
# 28   "Нягтлах тусам аюулгүй” аяныг хэрэгжүүлж эхэллээ
# 29  Зөвшөөрөлгүй гаражуудыг буулгаж, Өрхийн эрүүл ...
# 30                З.Энхболдоор заалгавал АН ялагдана!
# 31  Э.Оюунболдын цол хурааж, унасан бөхчүүдэд цол ...
# 32     Оросын хөлбөмбөгт одод цуглах боломжтой байжээ
# 33  Зайлшгүй шалтгаантай иргэдийг Улаанбаатарт нэв...
# 34                                      Яаж баяжив???
# 35  Covid-19 хүүхдээс том хүнд халддаггүй байж маг...
# 36  ТББХ: УИХ-ын тухай хуулийн шинэчилсэн найруулг...
# 37  Covid-19: Москва сарын дотор барьсан эмнэлгээ ...
# 38  Амтат шинэхэн жимсний шүүс бэлдэх амтлаг зөвлө...
# 39     Коронавируст халдварын нөхцөл байдлын мэдээлэл
# 40  "Халдвар авсан жолооч хүүтэйгээ уулзсан байж б...
# 41                     Трамп Ким Жон Унд сайныг хүсэв
# 42           Сургалтын төвүүд дампуурлаа зарлаж байна
# 43  "Л.Энхболд, Г.Солтан нарыг яллагдагчаар албада...
# 44    “Covid-19 терроризмын зэвсэг болж хувирч байна"
# 45    ОХУ-ын эмч коронавирусийн халдвараар нас барлаа
# 46  Засаг захиргаа, нутаг дэвсгэрийн нэгж, түүний ...
# 47           Эрх баригчдын дараагийн “золиос” хэн бэ?
# 48  10th Generation буюу хамгийн сүүлийн үеийн дес...
# 49       Лондоны загварын долоо хоног “хүйсгүй” болно
# 50  “Зорилготойгоор теле хичээл муу зааж байна гэж...
# 51  Сөүл, Франкфуртын тусгай нислэгт хамрагдах ирг...
#
#                Нийтлэлийн линк
# 0   https://news.mn/r/2291145/
# 1   https://news.mn/r/2291147/
# 2   https://news.mn/r/2291140/
# 3   https://news.mn/r/2291136/
# 4   https://news.mn/r/2291127/
# 5   https://news.mn/r/2291111/
# 6   https://news.mn/r/2291063/
# 7   https://news.mn/r/2291080/
# 8   https://news.mn/r/2290981/
# 9   https://news.mn/r/2291000/
# 10  https://news.mn/r/2290986/
# 11  https://news.mn/r/2290994/
# 12  https://news.mn/r/2291139/
# 13  https://news.mn/r/2291247/
# 14  https://news.mn/r/2291203/
# 15  https://news.mn/r/2291196/
# 16  https://news.mn/r/2291158/
# 17  https://news.mn/r/2291157/
# 18  https://news.mn/r/2291145/
# 19  https://news.mn/r/2291147/
# 20  https://news.mn/r/2291140/
# 21  https://news.mn/r/2291136/
# 22  https://news.mn/r/2291130/
# 23  https://news.mn/r/2291127/
# 24  https://news.mn/r/2291111/
# 25  https://news.mn/r/2291120/
# 26  https://news.mn/r/2291112/
# 27  https://news.mn/r/2291107/
# 28  https://news.mn/r/2291101/
# 29  https://news.mn/r/2291063/
# 30  https://news.mn/r/2291072/
# 31  https://news.mn/r/2291089/
# 32  https://news.mn/r/2291062/
# 33  https://news.mn/r/2291080/
# 34  https://news.mn/r/2291070/
# 35  https://news.mn/r/2291064/
# 36  https://news.mn/r/2291022/
# 37  https://news.mn/r/2291014/
# 38  https://news.mn/r/2291009/
# 39  https://news.mn/r/2290981/
# 40  https://news.mn/r/2291000/
# 41  https://news.mn/r/2291017/
# 42  https://news.mn/r/2290986/
# 43  https://news.mn/r/2290994/
# 44  https://news.mn/r/2290978/
# 45  https://news.mn/r/2290991/
# 46  https://news.mn/r/2290958/
# 47  https://news.mn/r/2290821/
# 48  https://news.mn/r/2290970/
# 49  https://news.mn/r/2290963/
# 50  https://news.mn/r/2290886/
# 51  https://news.mn/r/2290955/

# %% [markdown]
# ### Нэг функц болгох хугацааг хэмжих

# %% [markdown]
# Энэ скрипт нь мэдээ авахад хэр их цаг хугацаа шаардагдахыг сонирхож байна. Үүний тулд бид бүгдийг нэг функц болгон байрлуулаад дараа нь дуудна.

# %%
def news_crawler():
    # url тодорхойлох
    url = "https://news.mn/angilal/ediin-zasag/"

    # Хүсэлт
    r1 = requests.get(url)
    r1.status_code

    # Нүүр хуудасны агуулгыг хадгалах болно
    coverpage = r1.content

    # Soup үүсгэх
    soup1 = BeautifulSoup(coverpage, 'html5lib')

    # Мэдээ таних
    coverpage_news = soup1.find_all('h1', class_='entry-title')
    len(coverpage_news)
    
    number_of_articles = 5

    # Контент, холбоос, гарчигийн хоосон жагсаалт
    news_contents = []
    list_links = []
    list_titles = []

    for n in np.arange(0, number_of_articles):

        # Нийтлэл биш тул "live" хуудсыг орхих хэрэгтэй
        if "live" in coverpage_news[n].find('a')['href']:  
            continue

        # Нийтлэлийн холбоосыг авч байна
        link = coverpage_news[n].find('a')['href']
        list_links.append(link)

        # Гарчиг авч байна
        title = coverpage_news[n].find('a').get_text()
        list_titles.append(title)

        # Агуулга унших (энэ нь догол мөрүүдээр хуваагдана)
        article = requests.get(link)
        article_content = article.content
        soup_article = BeautifulSoup(article_content, 'html5lib')
        body = soup_article.find_all('div', class_='has-content-area')
        x = body[0].find_all('p')

        # Догол мөрүүдийг нэгтгэх
        list_paragraphs = []
        for p in np.arange(0, len(x)):
            paragraph = x[p].get_text()
            list_paragraphs.append(paragraph)
            final_article = " ".join(list_paragraphs)

        news_contents.append(final_article)

    # df_features
    df_features = pd.DataFrame(
         {'Мэдээлэл': news_contents 
        })

    # df_show_info
    df_show_info = pd.DataFrame(
        {'Мэдээний гарчиг': list_titles,
         'Мэдээний линк': list_links,
         'Мэдээллийн сайт': 'News.mn'})

    
    return (df_features, df_show_info)

# %%
start = time.time()
x, y = get_news_theguardian()
end =time.time()
te = end-start
print("Нийт хугацаа нь %f секунд байна." %(te))
# Out:
# Нийт хугацаа нь 5.289670 секунд байна.
